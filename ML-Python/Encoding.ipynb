# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# Load the Dataset:

# %%
data =  pd.read_csv('car price.csv')

# %%
data.head()
# Out:
#          Id Manufacturer         Model  Prod_Year   Category Leather_Interioe  \
# 0  45624039         FORD       Mustang       2016  Cabriolet              Yes
# 1  45766794   MITSUBISHI        Pajero       1997       Jeep               No
# 2  45709646       TOYOTA         RAV 4       2001       Jeep               No
# 3  45816588       SUZUKI  Grand Vitara       2008       Jeep               No
# 4  45759758   MITSUBISHI   Pajero Mini       2006       Jeep               No
#
#   Fuel_Type Engine Volume  Kilometers_Driven Gear_Box_Type Drive_Wheel  \
# 0    Petrol     2.3 Turbo            75000.0     Tiptronic        Rear
# 1    Petrol           2.4           142000.0     Automatic         4x4
# 2    Petrol             2            91000.0     Automatic         4x4
# 3    Petrol           1.6            98000.0     Automatic         4x4
# 4    Petrol           0.7           314000.0        Manual         4x4
#
#   Selling_Date             Wheel   Color  Airbags   Price
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4819 entries, 0 to 4818
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 4819 non-null   int64
#  1   Manufacturer       4819 non-null   object
#  2   Model              4819 non-null   object
#  3   Prod_Year          4819 non-null   int64
#  4   Category           4819 non-null   object
#  5   Leather_Interioe   4819 non-null   object
#  6   Fuel_Type          4819 non-null   object
#  7   Engine Volume      4819 non-null   object
#  8   Kilometers_Driven  4733 non-null   float64
#  9   Gear_Box_Type      4819 non-null   object
#  10  Drive_Wheel        4819 non-null   object
#  11  Selling_Date       4819 non-null   object
#  12  Wheel              4819 non-null   object
#  13  Color              4819 non-null   object
#  14  Airbags            4650 non-null   float64
#  15  Price              4819 non-null   int64
# ...

# %%
data.select_dtypes(['object']).head(6)
# Out:
#   Manufacturer         Model   Category Leather_Interioe Fuel_Type  \
# 0         FORD       Mustang  Cabriolet              Yes    Petrol
# 1   MITSUBISHI        Pajero       Jeep               No    Petrol
# 2       TOYOTA         RAV 4       Jeep               No    Petrol
# 3       SUZUKI  Grand Vitara       Jeep               No    Petrol
# 4   MITSUBISHI   Pajero Mini       Jeep               No    Petrol
# 5       SUZUKI         Jimny       Jeep               No    Petrol
#
#   Engine Volume Gear_Box_Type Drive_Wheel Selling_Date             Wheel  \
# 0     2.3 Turbo     Tiptronic        Rear   02-03-2023        Left wheel
# 1           2.4     Automatic         4x4   02-03-2023        Left wheel
# 2             2     Automatic         4x4   02-03-2023  Right-hand drive
# 3           1.6     Automatic         4x4   02-03-2023        Left wheel
# 4           0.7        Manual         4x4   02-03-2023  Right-hand drive
# ...

# %%
data1 = data

# %%
print(type(data1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# LABEL ENCODING

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencode = LabelEncoder()

# %%
data['Gear_Box_Type'].value_counts()
# Out:
# Gear_Box_Type
# Automatic    3365
# Tiptronic    1149
# Manual        305
# Name: count, dtype: int64

# %%
data['Gear_Box_Type'] = labelencode.fit_transform(data['Gear_Box_Type'])

# %%
data['Gear_Box_Type'].value_counts()
# Out:
# Gear_Box_Type
# 0    3365
# 2    1149
# 1     305
# Name: count, dtype: int64

# %%
data.head()
# Out:
#          Id Manufacturer         Model  Prod_Year   Category Leather_Interioe  \
# 0  45624039         FORD       Mustang       2016  Cabriolet              Yes
# 1  45766794   MITSUBISHI        Pajero       1997       Jeep               No
# 2  45709646       TOYOTA         RAV 4       2001       Jeep               No
# 3  45816588       SUZUKI  Grand Vitara       2008       Jeep               No
# 4  45759758   MITSUBISHI   Pajero Mini       2006       Jeep               No
#
#   Fuel_Type Engine Volume  Kilometers_Driven  Gear_Box_Type Drive_Wheel  \
# 0    Petrol     2.3 Turbo            75000.0              2        Rear
# 1    Petrol           2.4           142000.0              0         4x4
# 2    Petrol             2            91000.0              0         4x4
# 3    Petrol           1.6            98000.0              0         4x4
# 4    Petrol           0.7           314000.0              1         4x4
#
#   Selling_Date             Wheel   Color  Airbags   Price
# ...

# %%
data.select_dtypes(['object']).head(6)
# Out:
#   Manufacturer         Model   Category Leather_Interioe Fuel_Type  \
# 0         FORD       Mustang  Cabriolet              Yes    Petrol
# 1   MITSUBISHI        Pajero       Jeep               No    Petrol
# 2       TOYOTA         RAV 4       Jeep               No    Petrol
# 3       SUZUKI  Grand Vitara       Jeep               No    Petrol
# 4   MITSUBISHI   Pajero Mini       Jeep               No    Petrol
# 5       SUZUKI         Jimny       Jeep               No    Petrol
#
#   Engine Volume Drive_Wheel Selling_Date             Wheel   Color
# 0     2.3 Turbo        Rear   02-03-2023        Left wheel  Silver
# 1           2.4         4x4   02-03-2023        Left wheel    Blue
# 2             2         4x4   02-03-2023  Right-hand drive  Silver
# 3           1.6         4x4   02-03-2023        Left wheel   Black
# 4           0.7         4x4   02-03-2023  Right-hand drive  Silver
# 5           1.3         4x4   02-03-2023        Left wheel   Green

# %%
data['Category'] = labelencode.fit_transform(data['Category'])

# %%
data.head()
# Out:
#          Id Manufacturer         Model  Prod_Year  Category Leather_Interioe  \
# 0  45624039         FORD       Mustang       2016         0              Yes
# 1  45766794   MITSUBISHI        Pajero       1997         1               No
# 2  45709646       TOYOTA         RAV 4       2001         1               No
# 3  45816588       SUZUKI  Grand Vitara       2008         1               No
# 4  45759758   MITSUBISHI   Pajero Mini       2006         1               No
#
#   Fuel_Type Engine Volume  Kilometers_Driven  Gear_Box_Type Drive_Wheel  \
# 0    Petrol     2.3 Turbo            75000.0              2        Rear
# 1    Petrol           2.4           142000.0              0         4x4
# 2    Petrol             2            91000.0              0         4x4
# 3    Petrol           1.6            98000.0              0         4x4
# 4    Petrol           0.7           314000.0              1         4x4
#
#   Selling_Date             Wheel   Color  Airbags   Price
# ...

# %%
data['Wheel'] = labelencode.fit_transform(data['Wheel'])

# %%
data['Color'] = labelencode.fit_transform(data['Color'])

# %%
data.select_dtypes(['object'])
# Out:
#        Manufacturer         Model Leather_Interioe Fuel_Type Engine Volume  \
# 0              FORD       Mustang              Yes    Petrol     2.3 Turbo
# 1        MITSUBISHI        Pajero               No    Petrol           2.4
# 2            TOYOTA         RAV 4               No    Petrol             2
# 3            SUZUKI  Grand Vitara               No    Petrol           1.6
# 4        MITSUBISHI   Pajero Mini               No    Petrol           0.7
# ...             ...           ...              ...       ...           ...
# 4814          LEXUS        IS 250              Yes    Petrol           2.5
# 4815            BMW           528              Yes    Petrol     2.0 Turbo
# 4816           FORD        Escape              Yes    Petrol             3
# 4817         TOYOTA  Land Cruiser              Yes    Petrol           4.7
# 4818  MERCEDES-BENZ         E 350              Yes    Petrol           3.5
#
#      Drive_Wheel Selling_Date
# 0           Rear   02-03-2023
# ...

# %%
data['Drive_Wheel'] = labelencode.fit_transform(data['Drive_Wheel'])

# %%
data['Manufacturer'] = labelencode.fit_transform(data['Manufacturer'])

# %%
data
# Out:
#             Id  Manufacturer         Model  Prod_Year  Category  \
# 0     45624039            13       Mustang       2016         0
# 1     45766794            34        Pajero       1997         1
# 2     45709646            45         RAV 4       2001         1
# 3     45816588            43  Grand Vitara       2008         1
# 4     45759758            34   Pajero Mini       2006         1
# ...        ...           ...           ...        ...       ...
# 4814  45602856            27        IS 250       2015         3
# 4815  45089354             3           528       2014         3
# 4816  45264871            13        Escape       2011         1
# 4817  45510310            45  Land Cruiser       2008         1
# 4818  45801572            31         E 350       2012         3
#
#      Leather_Interioe Fuel_Type Engine Volume  Kilometers_Driven  \
# 0                 Yes    Petrol     2.3 Turbo            75000.0
# ...

# %%
data['Model'] = labelencode.fit_transform(data['Model'])

# %%
data
# Out:
#             Id  Manufacturer  Model  Prod_Year  Category Leather_Interioe  \
# 0     45624039            13    467       2016         0              Yes
# 1     45766794            34    495       1997         1               No
# 2     45709646            45    531       2001         1               No
# 3     45816588            43    360       2008         1               No
# 4     45759758            34    497       2006         1               No
# ...        ...           ...    ...        ...       ...              ...
# 4814  45602856            27    379       2015         3              Yes
# 4815  45089354             3     54       2014         3              Yes
# 4816  45264871            13    289       2011         1              Yes
# 4817  45510310            45    416       2008         1              Yes
# 4818  45801572            31    255       2012         3              Yes
#
#      Fuel_Type Engine Volume  Kilometers_Driven  Gear_Box_Type  Drive_Wheel  \
# ...

# %% [markdown]
# One hot Encoding

# %%
columns_to_one_hot_encode = [ 'Drive_Wheel','Leather_Interioe','Fuel_Type','Category']

# %%
df = pd.get_dummies(data1 , columns=columns_to_one_hot_encode,drop_first=True,dtype=int)

# %%
df.shape
# Out:
# (4819, 21)

# %%
df
# Out:
#             Id  Manufacturer         Model  Prod_Year Engine Volume  \
# 0     45624039            13       Mustang       2016     2.3 Turbo
# 1     45766794            34        Pajero       1997           2.4
# 2     45709646            45         RAV 4       2001             2
# 3     45816588            43  Grand Vitara       2008           1.6
# 4     45759758            34   Pajero Mini       2006           0.7
# ...        ...           ...           ...        ...           ...
# 4814  45602856            27        IS 250       2015           2.5
# 4815  45089354             3           528       2014     2.0 Turbo
# 4816  45264871            13        Escape       2011             3
# 4817  45510310            45  Land Cruiser       2008           4.7
# 4818  45801572            31         E 350       2012           3.5
#
#       Kilometers_Driven  Gear_Box_Type Selling_Date  Wheel  Color  ...  \
# 0               75000.0              2   02-03-2023      0     12  ...
# ...
